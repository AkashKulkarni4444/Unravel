# %%
# !pip install fastapi uvicorn seaborn xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: fastapi in /home/aaravnigam/.local/lib/python3.12/site-packages (0.104.1)
# Requirement already satisfied: uvicorn in /home/aaravnigam/.local/lib/python3.12/site-packages (0.24.0.post1)
# Requirement already satisfied: seaborn in /home/aaravnigam/.local/lib/python3.12/site-packages (0.13.0)
# Requirement already satisfied: xgboost in /home/aaravnigam/.local/lib/python3.12/site-packages (2.0.2)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /home/aaravnigam/.local/lib/python3.12/site-packages (from fastapi) (3.7.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /home/aaravnigam/.local/lib/python3.12/site-packages (from fastapi) (2.5.2)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /home/aaravnigam/.local/lib/python3.12/site-packages (from fastapi) (0.27.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/lib/python3.12/site-packages (from fastapi) (4.8.0)
# Requirement already satisfied: click>=7.0 in /usr/lib/python3.12/site-packages (from uvicorn) (8.1.3)
# Requirement already satisfied: h11>=0.8 in /home/aaravnigam/.local/lib/python3.12/site-packages (from uvicorn) (0.14.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/aaravnigam/.local/lib/python3.12/site-packages (from seaborn) (1.26.2)
# Requirement already satisfied: pandas>=1.2 in /home/aaravnigam/.local/lib/python3.12/site-packages (from seaborn) (2.1.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in /home/aaravnigam/.local/lib/python3.12/site-packages (from seaborn) (3.8.2)
# Requirement already satisfied: scipy in /home/aaravnigam/.local/lib/python3.12/site-packages (from xgboost) (1.11.4)
# Requirement already satisfied: idna>=2.8 in /usr/lib/python3.12/site-packages (from anyio<4.0.0,>=3.7.1->fastapi) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /home/aaravnigam/.local/lib/python3.12/site-packages (from anyio<4.0.0,>=3.7.1->fastapi) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/aaravnigam/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/aaravnigam/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/aaravnigam/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/aaravnigam/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.1)
# Requirement already satisfied: pillow>=8 in /usr/lib64/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/aaravnigam/.local/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/aaravnigam/.local/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/aaravnigam/.local/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /home/aaravnigam/.local/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.14.5)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("insurance.csv")
df
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %% [markdown]
# # Now Lets Perform some EDA to build a Good Model

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
features = ['sex', 'smoker', 'region']
 
plt.subplots(figsize=(20, 10))
for i, col in enumerate(features):
    plt.subplot(1, 3,i+1)
 
    x = df[col].value_counts()
    plt.pie(x.values,
            labels=x.index,
            autopct='%1.1f%%')
 
plt.show()

# %%
features = ['age', 'bmi']
 
plt.subplots(figsize=(17, 7))
for i, col in enumerate(features):
    plt.subplot(1, 2, i + 1)
    sns.scatterplot(data=df, x=col,
                   y='expenses',
                   hue='smoker')
plt.show()

# %%
df.drop_duplicates(inplace=True)
sns.boxplot(df['age'])
# Out:
# <Axes: ylabel='age'>

# %%
sns.boxplot(df['bmi'])
# Out:
# <Axes: ylabel='bmi'>

# %%
Q1=df['bmi'].quantile(0.25)
Q2=df['bmi'].quantile(0.5)
Q3=df['bmi'].quantile(0.75)
iqr=Q3-Q1
lowlim=Q1-1.5*iqr
upplim=Q3+1.5*iqr
print(lowlim)
print(upplim)
# Out:
# 13.699999999999998
# 47.300000000000004

# %%
df = df[(df["bmi"] > lowlim) & (df["bmi"] < upplim)]
sns.boxplot(df['bmi'])
# Out:
# <Axes: ylabel='bmi'>

# %%
df['bmi'].skew()
df['age'].skew()
# Out:
# 0.057520907909550154

# %%
df['sex']=df['sex'].map({'male':0,'female':1})
df['smoker']=df['smoker'].map({'yes':1,'no':0})
df['region']=df['region'].map({'northwest':0, 'northeast':1,'southeast':2,'southwest':3})

# %%
df.corr()
# Out:
#                age       sex       bmi  children    smoker    region  expenses
# age       1.000000  0.018089  0.114857  0.042103 -0.025075  0.002121  0.301317
# sex       0.018089  1.000000 -0.039979 -0.019973 -0.080269 -0.008075 -0.064161
# bmi       0.114857 -0.039979  1.000000  0.017245 -0.002642  0.152831  0.193516
# children  0.042103 -0.019973  0.017245  1.000000  0.007234 -0.002338  0.069125
# smoker   -0.025075 -0.080269 -0.002642  0.007234  1.000000  0.010178  0.785896
# region    0.002121 -0.008075  0.152831 -0.002338  0.010178  1.000000  0.006708
# expenses  0.301317 -0.064161  0.193516  0.069125  0.785896  0.006708  1.000000

# %%
X=df.drop(['expenses'],axis=1)
Y=df[['expenses']]
from sklearn.linear_model import LinearRegression,Lasso
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
import xgboost
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
l1=[]
l2=[]
l3=[]
cvs=0
for i in range(40,50):
 xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.2,random_state=i)
 lrmodel=LinearRegression()
 lrmodel.fit(xtrain,ytrain)
 l1.append(lrmodel.score(xtrain,ytrain))
 l2.append(lrmodel.score(xtest,ytest))
 cvs=(cross_val_score(lrmodel,X,Y,cv=5,)).mean()
 l3.append(cvs)
 df1=pd.DataFrame({'train acc':l1,'test acc':l2,'cvs':l3})
df1
# Out:
#    train acc  test acc       cvs
# 0   0.748859  0.750078  0.746188
# 1   0.755306  0.695671  0.746188
# 2   0.749715  0.746532  0.746188
# 3   0.749959  0.745429  0.746188
# 4   0.747835  0.753664  0.746188
# 5   0.752686  0.734877  0.746188
# 6   0.742279  0.777878  0.746188
# 7   0.757097  0.716831  0.746188
# 8   0.750982  0.739328  0.746188
# 9   0.752888  0.731547  0.746188

# %%
from sklearn.metrics import r2_score
svrmodel=SVR()
svrmodel.fit(xtrain,ytrain)
ypredtrain1=svrmodel.predict(xtrain)
ypredtest1=svrmodel.predict(xtest)
print(r2_score(ytrain,ypredtrain1))
print(r2_score(ytest,ypredtest1))
print(cross_val_score(svrmodel,X,Y,cv=5,).mean())
# Out:
# -0.10903636675595307
# -0.13664734110131116
# -0.10436951211057437

# %%
rfmodel=RandomForestRegressor(random_state=42)
rfmodel.fit(xtrain,ytrain)
ypredtrain2=rfmodel.predict(xtrain)
ypredtest2=rfmodel.predict(xtest)
print(r2_score(ytrain,ypredtrain2))
print(r2_score(ytest,ypredtest2))
print(cross_val_score(rfmodel,X,Y,cv=5,).mean())
from sklearn.model_selection import GridSearchCV
estimator=RandomForestRegressor(random_state=42)
param_grid={'n_estimators':[10,40,50,98,100,120,150]}
grid=GridSearchCV(estimator,param_grid,scoring="r2",cv=5)
grid.fit(xtrain,ytrain)
print(grid.best_params_)
rfmodel=RandomForestRegressor(random_state=42,n_estimators=120)
rfmodel.fit(xtrain,ytrain)
ypredtrain2=rfmodel.predict(xtrain)
ypredtest2=rfmodel.predict(xtest)
print(r2_score(ytrain,ypredtrain2))
print(r2_score(ytest,ypredtest2))
print(cross_val_score(rfmodel,X,Y,cv=5,).mean())
# Out:
# 0.9756590681897747
# 0.8189017907370776
# 0.8346087606936361
# {'n_estimators': 150}
# 0.975949663024642
# 0.817413075029754
# 0.8347772273273091

# %%
gbmodel=GradientBoostingRegressor()
gbmodel.fit(xtrain,ytrain)
ypredtrain3=gbmodel.predict(xtrain)
ypredtest3=gbmodel.predict(xtest)
print(r2_score(ytrain,ypredtrain3))
print(r2_score(ytest,ypredtest3))
print(cross_val_score(gbmodel,X,Y,cv=5,).mean())
from sklearn.model_selection import GridSearchCV
estimator=GradientBoostingRegressor()
param_grid={'n_estimators':[10,15,19,20,21,50],'learning_rate':[0.1,0.19,0.2,0.21,0.8,1]}
grid=GridSearchCV(estimator,param_grid,scoring="r2",cv=5)
grid.fit(xtrain,ytrain)
print(grid.best_params_)
gbmodel=GradientBoostingRegressor(n_estimators=19,learning_rate=0.2)
gbmodel.fit(xtrain,ytrain)
ypredtrain3=gbmodel.predict(xtrain)
ypredtest3=gbmodel.predict(xtest)
print(r2_score(ytrain,ypredtrain3))
print(r2_score(ytest,ypredtest3))
print(cross_val_score(gbmodel,X,Y,cv=5,).mean())
# Out:
# 0.901213281943248
# 0.8567323178012809
# 0.8523529457968099
# {'learning_rate': 0.21, 'n_estimators': 19}
# 0.8799835711637227
# 0.8575495996926119
# 0.8585667291352124

# %%
xgmodel=xgboost.XGBRegressor()
xgmodel.fit(xtrain,ytrain)
ypredtrain4=xgmodel.predict(xtrain)
ypredtest4=xgmodel.predict(xtest)
print(r2_score(ytrain,ypredtrain4))
print(r2_score(ytest,ypredtest4))
print(cross_val_score(xgmodel,X,Y,cv=5,).mean())
from sklearn.model_selection import GridSearchCV
estimator=xgboost.XGBRegressor()
param_grid={'n_estimators':[10,15,20,40,50],'max_depth':[3,4,5],'gamma':[0,0.15,0.3,0.5,1]}
grid=GridSearchCV(estimator,param_grid,scoring="r2",cv=5)
grid.fit(xtrain,ytrain)
print(grid.best_params_)
xgmodel=xgboost.XGBRegressor(n_estimators=15,max_depth=3,gamma=0)
xgmodel.fit(xtrain,ytrain)
ypredtrain4=xgmodel.predict(xtrain)
ypredtest4=xgmodel.predict(xtest)
print(r2_score(ytrain,ypredtrain4))
print(r2_score(ytest,ypredtest4))
print(cross_val_score(xgmodel,X,Y,cv=5,).mean())
# Out:
# 0.9939920198960479
# 0.7970538383244772
# 0.8035167850553455
# {'gamma': 0, 'max_depth': 3, 'n_estimators': 15}
# 0.8820195580129184
# 0.8590115388387327
# 0.8580913446968635

# %%
xgmodel=xgboost.XGBRegressor()
xgmodel.fit(xtrain,ytrain)
ypredtrain4=xgmodel.predict(xtrain)
ypredtest4=xgmodel.predict(xtest)
print(r2_score(ytrain,ypredtrain4))
print(r2_score(ytest,ypredtest4))
print(cross_val_score(xgmodel,X,Y,cv=5,).mean())
from sklearn.model_selection import GridSearchCV
estimator=xgboost.XGBRegressor()
param_grid={'n_estimators':[10,15,20,40,50],'max_depth':[3,4,5],'gamma':[0,0.15,0.3,0.5,1]}
grid=GridSearchCV(estimator,param_grid,scoring="r2",cv=5)
grid.fit(xtrain,ytrain)
print(grid.best_params_)
xgmodel=xgboost.XGBRegressor(n_estimators=15,max_depth=3,gamma=0)
xgmodel.fit(xtrain,ytrain)
ypredtrain4=xgmodel.predict(xtrain)
ypredtest4=xgmodel.predict(xtest)
print(r2_score(ytrain,ypredtrain4))
print(r2_score(ytest,ypredtest4))
print(cross_val_score(xgmodel,X,Y,cv=5,).mean())
# Out:
# 0.9939920198960479
# 0.7970538383244772
# 0.8035167850553455
# {'gamma': 0, 'max_depth': 3, 'n_estimators': 15}
# 0.8820195580129184
# 0.8590115388387327
# 0.8580913446968635

# %%
feats=pd.DataFrame(data=grid.best_estimator_.feature_importances_,index=X.columns,columns=['Importance'])
feats
# Out:
#           Importance
# age         0.038236
# sex         0.000267
# bmi         0.080660
# children    0.011095
# smoker      0.864994
# region      0.004749

# %%
important_features=feats[feats['Importance']>0.01]
important_features
# Out:
#           Importance
# age         0.038236
# bmi         0.080660
# children    0.011095
# smoker      0.864994

# %%
df.drop(df[['sex','region']],axis=1,inplace=True)
Xf=df.drop(df[['expenses']],axis=1)
X=df.drop(df[['expenses']],axis=1)
xtrain,xtest,ytrain,ytest=train_test_split(Xf,Y,test_size=0.2,random_state=42)
finalmodel=xgboost.XGBRegressor(n_estimators=15,max_depth=3,gamma=0)
finalmodel.fit(xtrain,ytrain)
ypredtrain4=finalmodel.predict(xtrain)
ypredtest4=finalmodel.predict(xtest)
print(r2_score(ytrain,ypredtrain4))
print(r2_score(ytest,ypredtest4))
print(cross_val_score(finalmodel,X,Y,cv=5,).mean())
# Out:
# 0.8810945174676232
# 0.8540053000246788
# 0.8577427630973077

# %%
import pickle


# Save the trained model using pickle
with open('expense_predictor_model.pkl', 'wb') as model_file:
    pickle.dump(finalmodel, model_file)

# %%
finalmodel.predict([[35,24.1,1,1]])
# Out:
# array([18785.355], dtype=float32)
